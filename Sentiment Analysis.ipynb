# %%
"""
Sentiment Analysis using TextBlob
"""

import praw
from textblob import TextBlob
import pandas as pd
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Reddit API credentials
reddit_client_id = 'NgboStGHqM88bILBVSkjnQ'
reddit_client_secret = '-ik8I0QbDR5wmZZdKdpd_L_6KVoN0Q'
reddit_username = 'UnusualAd8451'
reddit_password = 'datamining1234'
reddit_user_agent = 'SentimentAnalysisBot/0.1'

# Authenticate with the Reddit API using PRAW
reddit = praw.Reddit(client_id=reddit_client_id, 
                     client_secret=reddit_client_secret, 
                     username=reddit_username, 
                     password=reddit_password, 
                     user_agent=reddit_user_agent)

# Function to preprocess post text
def preprocess_post(post):
    # Remove URLs
    post = re.sub(r'http\S+|www\S+|https\S+', '', post, flags=re.MULTILINE)
    
    # Remove special characters and numbers
    post = re.sub(r'\W', ' ', post)
    post = re.sub(r'\d', ' ', post)
    
    # Convert to lowercase
    post = post.lower()
    
    # Tokenize
    tokens = word_tokenize(post)
    
    # Remove stop words and stem the remaining words
    stop_words = set(stopwords.words('english'))
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens if token not in stop_words and len(token) > 2]
    
    # Reconstruct the preprocessed post text
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# List of subreddits to collect posts and analyze sentiment for
subreddits = ["apple", "microsoft", "amazon", "teslamotors", "google"]

# List to store preprocessed posts
preprocessed_posts = []

# List to store raw posts
raw_posts = []

# List to store sentiment scores for each subreddit
sentiment_scores = []

# List to store sentiment descriptions for each score
sentiment_descriptions = []

# Loop through each subreddit and collect 1000 posts
for subreddit in subreddits:
    print(f"Collecting posts for r/{subreddit}...")
    posts = reddit.subreddit(subreddit).hot(limit=1000)
    
    # Analyze the sentiment of each post
    for post in posts:
        # Preprocess the post text
        preprocessed_text = preprocess_post(post.title)
        preprocessed_posts.append(preprocessed_text)
        
        # Append the raw post text to the list
        raw_posts.append(post.title)
        
        # Analyze the sentiment of the preprocessed post text
        sentiment_score = TextBlob(preprocessed_text).sentiment.polarity
        sentiment_scores.append(sentiment_score)
        
        # Determine the sentiment description based on the sentiment score
        if sentiment_score > 0:
            sentiment_description = "Positive"
        elif sentiment_score < 0:
            sentiment_description = "Negative"
        else:
            sentiment_description = "Neutral"
        sentiment_descriptions.append(sentiment_description)

# Create a pandas dataframe to store the results
data = {"Subreddit": subreddits * len(preprocessed_posts),
        "Raw Text": raw_posts * len(subreddits),
        "Post": preprocessed_posts * len(subreddits), 
        "Sentiment Score": sentiment_scores * len(subreddits), 
        "Sentiment Description": sentiment_descriptions * len(subreddits)}
df = pd.DataFrame(data)

# Create separate dataframes for each company
apple_df = df[df['Subreddit'] == 'apple'].reset_index(drop=True)
print("\nApple Average Sentiment Score:", apple_df['Sentiment Score'].mean())
display(apple_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Apple DataFrame"))

microsoft_df = df[df['Subreddit'] == 'microsoft'].reset_index(drop=True)
print("Microsoft Average Sentiment Score:", microsoft_df['Sentiment Score'].mean())
display(microsoft_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Microsoft DataFrame"))

amazon_df = df[df['Subreddit'] == 'amazon'].reset_index(drop=True)
print("Amazon Average Sentiment Score:", amazon_df['Sentiment Score'].mean())
display(amazon_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Amazon DataFrame"))

tesla_df = df[df['Subreddit'] == 'teslamotors'].reset_index(drop=True)
print("Tesla Average Sentiment Score:", tesla_df['Sentiment Score'].mean())
display(tesla_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Tesla DataFrame"))

google_df = df[df['Subreddit'] == 'google'].reset_index(drop=True)
print("Google Average Sentiment Score:", google_df['Sentiment Score'].mean())
display(google_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Google DataFrame"))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/htootayzaaung/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/htootayzaaung/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Collecting posts for r/apple...
# Collecting posts for r/microsoft...
# Collecting posts for r/amazon...
# Collecting posts for r/teslamotors...
# Collecting posts for r/google...
#
# Apple Average Sentiment Score: 0.034010096725606655
# <style type="text/css">
# #T_5b24e th {
#   text-align: left;
# }
# #T_5b24e_row0_col0, #T_5b24e_row0_col1, #T_5b24e_row0_col2, #T_5b24e_row0_col3, #T_5b24e_row0_col4, #T_5b24e_row1_col0, #T_5b24e_row1_col1, #T_5b24e_row1_col2, #T_5b24e_row1_col3, #T_5b24e_row1_col4, #T_5b24e_row2_col0, #T_5b24e_row2_col1, #T_5b24e_row2_col2, #T_5b24e_row2_col3, #T_5b24e_row2_col4, #T_5b24e_row3_col0, #T_5b24e_row3_col1, #T_5b24e_row3_col2, #T_5b24e_row3_col3, #T_5b24e_row3_col4, #T_5b24e_row4_col0, #T_5b24e_row4_col1, #T_5b24e_row4_col2, #T_5b24e_row4_col3, #T_5b24e_row4_col4, #T_5b24e_row5_col0, #T_5b24e_row5_col1, #T_5b24e_row5_col2, #T_5b24e_row5_col3, #T_5b24e_row5_col4, #T_5b24e_row6_col0, #T_5b24e_row6_col1, #T_5b24e_row6_col2, #T_5b24e_row6_col3, #T_5b24e_row6_col4, #T_5b24e_row7_col0, #T_5b24e_row7_col1, #T_5b24e_row7_col2, #T_5b24e_row7_col3, #T_5b24e_row7_col4, #T_5b24e_row8_col0, #T_5b24e_row8_col1, #T_5b24e_row8_col2, #T_5b24e_row8_col3, #T_5b24e_row8_col4, #T_5b24e_row9_col0, #T_5b24e_row9_col1, #T_5b24e_row9_col2, #T_5b24e_row9_col3, #T_5b24e_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_5b24e">
#   <caption>Apple DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b24e_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_5b24e_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_5b24e_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_5b24e_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_5b24e_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b24e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b24e_row0_col0" class="data row0 col0" >apple</td>
#       <td id="T_5b24e_row0_col1" class="data row0 col1" >Daily Advice Thread - April 17, 2023</td>
#       <td id="T_5b24e_row0_col2" class="data row0 col2" >daili advic thread april</td>
#       <td id="T_5b24e_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_5b24e_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b24e_row1_col0" class="data row1 col0" >apple</td>
#       <td id="T_5b24e_row1_col1" class="data row1 col1" >Rumor: iPhone 15 to use 'frosted glass' finish, new 'cyan' color option</td>
#       <td id="T_5b24e_row1_col2" class="data row1 col2" >rumor iphon use frost glass finish new cyan color option</td>
#       <td id="T_5b24e_row1_col3" class="data row1 col3" >0.136364</td>
#       <td id="T_5b24e_row1_col4" class="data row1 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b24e_row2_col0" class="data row2 col0" >apple</td>
#       <td id="T_5b24e_row2_col1" class="data row2 col1" >Tim Cook spotted at Coachella with Eddy Cue</td>
#       <td id="T_5b24e_row2_col2" class="data row2 col2" >tim cook spot coachella eddi cue</td>
#       <td id="T_5b24e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_5b24e_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b24e_row3_col0" class="data row3 col0" >apple</td>
#       <td id="T_5b24e_row3_col1" class="data row3 col1" >Live in an apartment? Tired of buzzing people in? I made an app to turn any buzzer into a smart device</td>
#       <td id="T_5b24e_row3_col2" class="data row3 col2" >live apart tire buzz peopl made app turn buzzer smart devic</td>
#       <td id="T_5b24e_row3_col3" class="data row3 col3" >0.175325</td>
#       <td id="T_5b24e_row3_col4" class="data row3 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b24e_row4_col0" class="data row4 col0" >apple</td>
#       <td id="T_5b24e_row4_col1" class="data row4 col1" >Pockity: Simple personal budgeting and expense tracking for iOS & iPadOS</td>
#       <td id="T_5b24e_row4_col2" class="data row4 col2" >pockiti simpl person budget expens track io ipado</td>
#       <td id="T_5b24e_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_5b24e_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b24e_row5_col0" class="data row5 col0" >apple</td>
#       <td id="T_5b24e_row5_col1" class="data row5 col1" >Hello drivers on Reddit! I made a dashcam + turn-by-turn navigation app.</td>
#       <td id="T_5b24e_row5_col2" class="data row5 col2" >hello driver reddit made dashcam turn turn navig app</td>
#       <td id="T_5b24e_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_5b24e_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b24e_row6_col0" class="data row6 col0" >apple</td>
#       <td id="T_5b24e_row6_col1" class="data row6 col1" >‘A huge blunder’: GM’s decision to ditch Apple CarPlay, Android Auto sparks backlash</td>
#       <td id="T_5b24e_row6_col2" class="data row6 col2" >huge blunder decis ditch appl carplay android auto spark backlash</td>
#       <td id="T_5b24e_row6_col3" class="data row6 col3" >0.400000</td>
#       <td id="T_5b24e_row6_col4" class="data row6 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b24e_row7_col0" class="data row7 col0" >apple</td>
#       <td id="T_5b24e_row7_col1" class="data row7 col1" >If Apple doesn’t introduce something like “old-people mode” this WWDC then it has truly lost its magic.</td>
#       <td id="T_5b24e_row7_col2" class="data row7 col2" >appl introduc someth like old peopl mode wwdc truli lost magic</td>
#       <td id="T_5b24e_row7_col3" class="data row7 col3" >0.300000</td>
#       <td id="T_5b24e_row7_col4" class="data row7 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b24e_row8_col0" class="data row8 col0" >apple</td>
#       <td id="T_5b24e_row8_col1" class="data row8 col1" >Apple Makes Headway on New Mac Laptops as It Grapples With Slump</td>
#       <td id="T_5b24e_row8_col2" class="data row8 col2" >appl make headway new mac laptop grappl slump</td>
#       <td id="T_5b24e_row8_col3" class="data row8 col3" >0.136364</td>
#       <td id="T_5b24e_row8_col4" class="data row8 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_5b24e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b24e_row9_col0" class="data row9 col0" >apple</td>
#       <td id="T_5b24e_row9_col1" class="data row9 col1" >How Apple is making the chips that power its computers – and why its Macs are turning green</td>
#       <td id="T_5b24e_row9_col2" class="data row9 col2" >appl make chip power comput mac turn green</td>
#       <td id="T_5b24e_row9_col3" class="data row9 col3" >-0.200000</td>
#       <td id="T_5b24e_row9_col4" class="data row9 col4" >Negative</td>
#     </tr>
#   </tbody>
# </table>
# Microsoft Average Sentiment Score: 0.034010096725606696
# <style type="text/css">
# #T_cdada th {
#   text-align: left;
# }
# #T_cdada_row0_col0, #T_cdada_row0_col1, #T_cdada_row0_col2, #T_cdada_row0_col3, #T_cdada_row0_col4, #T_cdada_row1_col0, #T_cdada_row1_col1, #T_cdada_row1_col2, #T_cdada_row1_col3, #T_cdada_row1_col4, #T_cdada_row2_col0, #T_cdada_row2_col1, #T_cdada_row2_col2, #T_cdada_row2_col3, #T_cdada_row2_col4, #T_cdada_row3_col0, #T_cdada_row3_col1, #T_cdada_row3_col2, #T_cdada_row3_col3, #T_cdada_row3_col4, #T_cdada_row4_col0, #T_cdada_row4_col1, #T_cdada_row4_col2, #T_cdada_row4_col3, #T_cdada_row4_col4, #T_cdada_row5_col0, #T_cdada_row5_col1, #T_cdada_row5_col2, #T_cdada_row5_col3, #T_cdada_row5_col4, #T_cdada_row6_col0, #T_cdada_row6_col1, #T_cdada_row6_col2, #T_cdada_row6_col3, #T_cdada_row6_col4, #T_cdada_row7_col0, #T_cdada_row7_col1, #T_cdada_row7_col2, #T_cdada_row7_col3, #T_cdada_row7_col4, #T_cdada_row8_col0, #T_cdada_row8_col1, #T_cdada_row8_col2, #T_cdada_row8_col3, #T_cdada_row8_col4, #T_cdada_row9_col0, #T_cdada_row9_col1, #T_cdada_row9_col2, #T_cdada_row9_col3, #T_cdada_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_cdada">
#   <caption>Microsoft DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdada_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_cdada_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_cdada_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_cdada_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_cdada_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdada_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdada_row0_col0" class="data row0 col0" >microsoft</td>
#       <td id="T_cdada_row0_col1" class="data row0 col1" >Apple Announces WWDC 2023 Event Taking Place June 5 to 9</td>
#       <td id="T_cdada_row0_col2" class="data row0 col2" >appl announc wwdc event take place june</td>
#       <td id="T_cdada_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_cdada_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdada_row1_col0" class="data row1 col0" >microsoft</td>
#       <td id="T_cdada_row1_col1" class="data row1 col1" >Apple launches all-new ‘Apple Trade In’ website in time for Earth Day</td>
#       <td id="T_cdada_row1_col2" class="data row1 col2" >appl launch new appl trade websit time earth day</td>
#       <td id="T_cdada_row1_col3" class="data row1 col3" >0.136364</td>
#       <td id="T_cdada_row1_col4" class="data row1 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdada_row2_col0" class="data row2 col0" >microsoft</td>
#       <td id="T_cdada_row2_col1" class="data row2 col1" >Apple will lay sideloading groundwork in iOS 17</td>
#       <td id="T_cdada_row2_col2" class="data row2 col2" >appl lay sideload groundwork io</td>
#       <td id="T_cdada_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_cdada_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdada_row3_col0" class="data row3 col0" >microsoft</td>
#       <td id="T_cdada_row3_col1" class="data row3 col1" >Fanciful Fonts - add custom fonts and text effects to iMessage and more</td>
#       <td id="T_cdada_row3_col2" class="data row3 col2" >fanci font add custom font text effect imessag</td>
#       <td id="T_cdada_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cdada_row3_col4" class="data row3 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdada_row4_col0" class="data row4 col0" >microsoft</td>
#       <td id="T_cdada_row4_col1" class="data row4 col1" >iPhone 3g Commercial "There's An App For That" 2009</td>
#       <td id="T_cdada_row4_col2" class="data row4 col2" >iphon commerci app</td>
#       <td id="T_cdada_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_cdada_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cdada_row5_col0" class="data row5 col0" >microsoft</td>
#       <td id="T_cdada_row5_col1" class="data row5 col1" >The macOS version of Chrome gets a 10% increase in performance</td>
#       <td id="T_cdada_row5_col2" class="data row5 col2" >maco version chrome get increas perform</td>
#       <td id="T_cdada_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_cdada_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cdada_row6_col0" class="data row6 col0" >microsoft</td>
#       <td id="T_cdada_row6_col1" class="data row6 col1" >Why do stores have to individually roll out Apple pay in the US ? How does that work?</td>
#       <td id="T_cdada_row6_col2" class="data row6 col2" >store individu roll appl pay work</td>
#       <td id="T_cdada_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_cdada_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cdada_row7_col0" class="data row7 col0" >microsoft</td>
#       <td id="T_cdada_row7_col1" class="data row7 col1" >Siri on HomePod actively ruins the user experience</td>
#       <td id="T_cdada_row7_col2" class="data row7 col2" >siri homepod activ ruin user experi</td>
#       <td id="T_cdada_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_cdada_row7_col4" class="data row7 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cdada_row8_col0" class="data row8 col0" >microsoft</td>
#       <td id="T_cdada_row8_col1" class="data row8 col1" >This speech gives me goosebumps every time. It's the best Steve Jobs motivational speech. Also, the movie "Jobs" (2013) is my all-time favorite.</td>
#       <td id="T_cdada_row8_col2" class="data row8 col2" >speech give goosebump everi time best steve job motiv speech also movi job time favorit</td>
#       <td id="T_cdada_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_cdada_row8_col4" class="data row8 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_cdada_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cdada_row9_col0" class="data row9 col0" >microsoft</td>
#       <td id="T_cdada_row9_col1" class="data row9 col1" >Apple's iPhone SE 4 is reportedly a 5G engineering test, and not for sale</td>
#       <td id="T_cdada_row9_col2" class="data row9 col2" >appl iphon reportedli engin test sale</td>
#       <td id="T_cdada_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_cdada_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
# Amazon Average Sentiment Score: 0.03401009672560662
# <style type="text/css">
# #T_87070 th {
#   text-align: left;
# }
# #T_87070_row0_col0, #T_87070_row0_col1, #T_87070_row0_col2, #T_87070_row0_col3, #T_87070_row0_col4, #T_87070_row1_col0, #T_87070_row1_col1, #T_87070_row1_col2, #T_87070_row1_col3, #T_87070_row1_col4, #T_87070_row2_col0, #T_87070_row2_col1, #T_87070_row2_col2, #T_87070_row2_col3, #T_87070_row2_col4, #T_87070_row3_col0, #T_87070_row3_col1, #T_87070_row3_col2, #T_87070_row3_col3, #T_87070_row3_col4, #T_87070_row4_col0, #T_87070_row4_col1, #T_87070_row4_col2, #T_87070_row4_col3, #T_87070_row4_col4, #T_87070_row5_col0, #T_87070_row5_col1, #T_87070_row5_col2, #T_87070_row5_col3, #T_87070_row5_col4, #T_87070_row6_col0, #T_87070_row6_col1, #T_87070_row6_col2, #T_87070_row6_col3, #T_87070_row6_col4, #T_87070_row7_col0, #T_87070_row7_col1, #T_87070_row7_col2, #T_87070_row7_col3, #T_87070_row7_col4, #T_87070_row8_col0, #T_87070_row8_col1, #T_87070_row8_col2, #T_87070_row8_col3, #T_87070_row8_col4, #T_87070_row9_col0, #T_87070_row9_col1, #T_87070_row9_col2, #T_87070_row9_col3, #T_87070_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_87070">
#   <caption>Amazon DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87070_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_87070_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_87070_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_87070_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_87070_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87070_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87070_row0_col0" class="data row0 col0" >amazon</td>
#       <td id="T_87070_row0_col1" class="data row0 col1" >Apple Card’s new high-yield Savings account is now available, offering a 4.15 percent APY</td>
#       <td id="T_87070_row0_col2" class="data row0 col2" >appl card new high yield save account avail offer percent api</td>
#       <td id="T_87070_row0_col3" class="data row0 col3" >0.148182</td>
#       <td id="T_87070_row0_col4" class="data row0 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87070_row1_col0" class="data row1 col0" >amazon</td>
#       <td id="T_87070_row1_col1" class="data row1 col1" >Apple Savings Account: Arbitration Provision (Read!)</td>
#       <td id="T_87070_row1_col2" class="data row1 col2" >appl save account arbitr provis read</td>
#       <td id="T_87070_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_87070_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87070_row2_col0" class="data row2 col0" >amazon</td>
#       <td id="T_87070_row2_col1" class="data row2 col1" >Apple Plans to Launch More Than Just Its New Headset at WWDC</td>
#       <td id="T_87070_row2_col2" class="data row2 col2" >appl plan launch new headset wwdc</td>
#       <td id="T_87070_row2_col3" class="data row2 col3" >0.136364</td>
#       <td id="T_87070_row2_col4" class="data row2 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87070_row3_col0" class="data row3 col0" >amazon</td>
#       <td id="T_87070_row3_col1" class="data row3 col1" >Mac OS X 10.2 Jaguar Video - "Touching", 2002</td>
#       <td id="T_87070_row3_col2" class="data row3 col2" >mac jaguar video touch</td>
#       <td id="T_87070_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_87070_row3_col4" class="data row3 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87070_row4_col0" class="data row4 col0" >amazon</td>
#       <td id="T_87070_row4_col1" class="data row4 col1" >Apple is selling a 10 year old refurbished computer for £5149</td>
#       <td id="T_87070_row4_col2" class="data row4 col2" >appl sell year old refurbish comput</td>
#       <td id="T_87070_row4_col3" class="data row4 col3" >0.100000</td>
#       <td id="T_87070_row4_col4" class="data row4 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87070_row5_col0" class="data row5 col0" >amazon</td>
#       <td id="T_87070_row5_col1" class="data row5 col1" >Daily Advice Thread - April 16, 2023</td>
#       <td id="T_87070_row5_col2" class="data row5 col2" >daili advic thread april</td>
#       <td id="T_87070_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_87070_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87070_row6_col0" class="data row6 col0" >amazon</td>
#       <td id="T_87070_row6_col1" class="data row6 col1" >Apple reportedly testing 15-inch MacBook Air production</td>
#       <td id="T_87070_row6_col2" class="data row6 col2" >appl reportedli test inch macbook air product</td>
#       <td id="T_87070_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_87070_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87070_row7_col0" class="data row7 col0" >amazon</td>
#       <td id="T_87070_row7_col1" class="data row7 col1" >First iPhone. A Guided Tour by Apple</td>
#       <td id="T_87070_row7_col2" class="data row7 col2" >first iphon guid tour appl</td>
#       <td id="T_87070_row7_col3" class="data row7 col3" >0.250000</td>
#       <td id="T_87070_row7_col4" class="data row7 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87070_row8_col0" class="data row8 col0" >amazon</td>
#       <td id="T_87070_row8_col1" class="data row8 col1" >Apple TV 4K launching huge upgrade for sports fans this weekend — how to get it</td>
#       <td id="T_87070_row8_col2" class="data row8 col2" >appl launch huge upgrad sport fan weekend get</td>
#       <td id="T_87070_row8_col3" class="data row8 col3" >0.400000</td>
#       <td id="T_87070_row8_col4" class="data row8 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_87070_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87070_row9_col0" class="data row9 col0" >amazon</td>
#       <td id="T_87070_row9_col1" class="data row9 col1" >Why do I continue to see News+ stories headed “See these photos!” that contain no photos?</td>
#       <td id="T_87070_row9_col2" class="data row9 col2" >continu see news stori head see photo contain photo</td>
#       <td id="T_87070_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_87070_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
# Tesla Average Sentiment Score: 0.03401009672560666
# <style type="text/css">
# #T_fa0f4 th {
#   text-align: left;
# }
# #T_fa0f4_row0_col0, #T_fa0f4_row0_col1, #T_fa0f4_row0_col2, #T_fa0f4_row0_col3, #T_fa0f4_row0_col4, #T_fa0f4_row1_col0, #T_fa0f4_row1_col1, #T_fa0f4_row1_col2, #T_fa0f4_row1_col3, #T_fa0f4_row1_col4, #T_fa0f4_row2_col0, #T_fa0f4_row2_col1, #T_fa0f4_row2_col2, #T_fa0f4_row2_col3, #T_fa0f4_row2_col4, #T_fa0f4_row3_col0, #T_fa0f4_row3_col1, #T_fa0f4_row3_col2, #T_fa0f4_row3_col3, #T_fa0f4_row3_col4, #T_fa0f4_row4_col0, #T_fa0f4_row4_col1, #T_fa0f4_row4_col2, #T_fa0f4_row4_col3, #T_fa0f4_row4_col4, #T_fa0f4_row5_col0, #T_fa0f4_row5_col1, #T_fa0f4_row5_col2, #T_fa0f4_row5_col3, #T_fa0f4_row5_col4, #T_fa0f4_row6_col0, #T_fa0f4_row6_col1, #T_fa0f4_row6_col2, #T_fa0f4_row6_col3, #T_fa0f4_row6_col4, #T_fa0f4_row7_col0, #T_fa0f4_row7_col1, #T_fa0f4_row7_col2, #T_fa0f4_row7_col3, #T_fa0f4_row7_col4, #T_fa0f4_row8_col0, #T_fa0f4_row8_col1, #T_fa0f4_row8_col2, #T_fa0f4_row8_col3, #T_fa0f4_row8_col4, #T_fa0f4_row9_col0, #T_fa0f4_row9_col1, #T_fa0f4_row9_col2, #T_fa0f4_row9_col3, #T_fa0f4_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_fa0f4">
#   <caption>Tesla DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa0f4_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_fa0f4_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_fa0f4_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_fa0f4_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_fa0f4_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa0f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa0f4_row0_col0" class="data row0 col0" >teslamotors</td>
#       <td id="T_fa0f4_row0_col1" class="data row0 col1" >iPhone 15 Pro 'Action' Button to Replace Role of Volume Buttons When Performing a Power Off/Force Restart</td>
#       <td id="T_fa0f4_row0_col2" class="data row0 col2" >iphon pro action button replac role volum button perform power forc restart</td>
#       <td id="T_fa0f4_row0_col3" class="data row0 col3" >0.100000</td>
#       <td id="T_fa0f4_row0_col4" class="data row0 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa0f4_row1_col0" class="data row1 col0" >teslamotors</td>
#       <td id="T_fa0f4_row1_col1" class="data row1 col1" >LG Display developing new OLED etching tech for Apple</td>
#       <td id="T_fa0f4_row1_col2" class="data row1 col2" >display develop new ole etch tech appl</td>
#       <td id="T_fa0f4_row1_col3" class="data row1 col3" >0.136364</td>
#       <td id="T_fa0f4_row1_col4" class="data row1 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa0f4_row2_col0" class="data row2 col0" >teslamotors</td>
#       <td id="T_fa0f4_row2_col1" class="data row2 col1" >Rant: Apple’s software quality (control)</td>
#       <td id="T_fa0f4_row2_col2" class="data row2 col2" >rant appl softwar qualiti control</td>
#       <td id="T_fa0f4_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_fa0f4_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa0f4_row3_col0" class="data row3 col0" >teslamotors</td>
#       <td id="T_fa0f4_row3_col1" class="data row3 col1" >As a father in need for some relaxation I made a relaxing sounds app with 30 free sounds for you to create your own calming atmosphere. With a unique Thunderstorm Mode for a realistic experience and no annoying subscription or ads.</td>
#       <td id="T_fa0f4_row3_col2" class="data row3 col2" >father need relax made relax sound app free sound creat calm atmospher uniqu thunderstorm mode realist experi annoy subscript ad</td>
#       <td id="T_fa0f4_row3_col3" class="data row3 col3" >0.375000</td>
#       <td id="T_fa0f4_row3_col4" class="data row3 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa0f4_row4_col0" class="data row4 col0" >teslamotors</td>
#       <td id="T_fa0f4_row4_col1" class="data row4 col1" >AppleID and other services down</td>
#       <td id="T_fa0f4_row4_col2" class="data row4 col2" >appleid servic</td>
#       <td id="T_fa0f4_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_fa0f4_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa0f4_row5_col0" class="data row5 col0" >teslamotors</td>
#       <td id="T_fa0f4_row5_col1" class="data row5 col1" >CamPlan combines AR with AI to create modern floor plans and get interior design advice.</td>
#       <td id="T_fa0f4_row5_col2" class="data row5 col2" >camplan combin creat modern floor plan get interior design advic</td>
#       <td id="T_fa0f4_row5_col3" class="data row5 col3" >0.200000</td>
#       <td id="T_fa0f4_row5_col4" class="data row5 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa0f4_row6_col0" class="data row6 col0" >teslamotors</td>
#       <td id="T_fa0f4_row6_col1" class="data row6 col1" >AirPods Are a Tragedy</td>
#       <td id="T_fa0f4_row6_col2" class="data row6 col2" >airpod tragedi</td>
#       <td id="T_fa0f4_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_fa0f4_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa0f4_row7_col0" class="data row7 col0" >teslamotors</td>
#       <td id="T_fa0f4_row7_col1" class="data row7 col1" >Gurman: 15-Inch MacBook Air With M2-Like Chip Spotted in Developer Logs</td>
#       <td id="T_fa0f4_row7_col2" class="data row7 col2" >gurman inch macbook air like chip spot develop log</td>
#       <td id="T_fa0f4_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_fa0f4_row7_col4" class="data row7 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa0f4_row8_col0" class="data row8 col0" >teslamotors</td>
#       <td id="T_fa0f4_row8_col1" class="data row8 col1" >Daily Advice Thread - April 15, 2023</td>
#       <td id="T_fa0f4_row8_col2" class="data row8 col2" >daili advic thread april</td>
#       <td id="T_fa0f4_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_fa0f4_row8_col4" class="data row8 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_fa0f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa0f4_row9_col0" class="data row9 col0" >teslamotors</td>
#       <td id="T_fa0f4_row9_col1" class="data row9 col1" >Watched this today and had a huge wave of nostalgia</td>
#       <td id="T_fa0f4_row9_col2" class="data row9 col2" >watch today huge wave nostalgia</td>
#       <td id="T_fa0f4_row9_col3" class="data row9 col3" >0.400000</td>
#       <td id="T_fa0f4_row9_col4" class="data row9 col4" >Positive</td>
#     </tr>
#   </tbody>
# </table>
# Google Average Sentiment Score: 0.03401009672560665
# <style type="text/css">
# #T_be0c8 th {
#   text-align: left;
# }
# #T_be0c8_row0_col0, #T_be0c8_row0_col1, #T_be0c8_row0_col2, #T_be0c8_row0_col3, #T_be0c8_row0_col4, #T_be0c8_row1_col0, #T_be0c8_row1_col1, #T_be0c8_row1_col2, #T_be0c8_row1_col3, #T_be0c8_row1_col4, #T_be0c8_row2_col0, #T_be0c8_row2_col1, #T_be0c8_row2_col2, #T_be0c8_row2_col3, #T_be0c8_row2_col4, #T_be0c8_row3_col0, #T_be0c8_row3_col1, #T_be0c8_row3_col2, #T_be0c8_row3_col3, #T_be0c8_row3_col4, #T_be0c8_row4_col0, #T_be0c8_row4_col1, #T_be0c8_row4_col2, #T_be0c8_row4_col3, #T_be0c8_row4_col4, #T_be0c8_row5_col0, #T_be0c8_row5_col1, #T_be0c8_row5_col2, #T_be0c8_row5_col3, #T_be0c8_row5_col4, #T_be0c8_row6_col0, #T_be0c8_row6_col1, #T_be0c8_row6_col2, #T_be0c8_row6_col3, #T_be0c8_row6_col4, #T_be0c8_row7_col0, #T_be0c8_row7_col1, #T_be0c8_row7_col2, #T_be0c8_row7_col3, #T_be0c8_row7_col4, #T_be0c8_row8_col0, #T_be0c8_row8_col1, #T_be0c8_row8_col2, #T_be0c8_row8_col3, #T_be0c8_row8_col4, #T_be0c8_row9_col0, #T_be0c8_row9_col1, #T_be0c8_row9_col2, #T_be0c8_row9_col3, #T_be0c8_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_be0c8">
#   <caption>Google DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be0c8_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_be0c8_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_be0c8_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_be0c8_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_be0c8_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be0c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be0c8_row0_col0" class="data row0 col0" >google</td>
#       <td id="T_be0c8_row0_col1" class="data row0 col1" >Tim Cook is in Mumbai to launch Apple’s first store in India.</td>
#       <td id="T_be0c8_row0_col2" class="data row0 col2" >tim cook mumbai launch appl first store india</td>
#       <td id="T_be0c8_row0_col3" class="data row0 col3" >0.250000</td>
#       <td id="T_be0c8_row0_col4" class="data row0 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be0c8_row1_col0" class="data row1 col0" >google</td>
#       <td id="T_be0c8_row1_col1" class="data row1 col1" >watchOS 10 Described as Apple Watch's Biggest Software Update Since 2015</td>
#       <td id="T_be0c8_row1_col2" class="data row1 col2" >watcho describ appl watch biggest softwar updat sinc</td>
#       <td id="T_be0c8_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_be0c8_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be0c8_row2_col0" class="data row2 col0" >google</td>
#       <td id="T_be0c8_row2_col1" class="data row2 col1" >LockBit ransomware gang appears to be targeting Macs for the first time</td>
#       <td id="T_be0c8_row2_col2" class="data row2 col2" >lockbit ransomwar gang appear target mac first time</td>
#       <td id="T_be0c8_row2_col3" class="data row2 col3" >0.250000</td>
#       <td id="T_be0c8_row2_col4" class="data row2 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be0c8_row3_col0" class="data row3 col0" >google</td>
#       <td id="T_be0c8_row3_col1" class="data row3 col1" >Kroger Begins Accepting Apple Pay After Years of Holding Out</td>
#       <td id="T_be0c8_row3_col2" class="data row3 col2" >kroger begin accept appl pay year hold</td>
#       <td id="T_be0c8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_be0c8_row3_col4" class="data row3 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be0c8_row4_col0" class="data row4 col0" >google</td>
#       <td id="T_be0c8_row4_col1" class="data row4 col1" >Asahi Linux: The team managed to get the Touch Bar working under Linux with KDE, as a secondary display</td>
#       <td id="T_be0c8_row4_col2" class="data row4 col2" >asahi linux team manag get touch bar work linux kde secondari display</td>
#       <td id="T_be0c8_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_be0c8_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be0c8_row5_col0" class="data row5 col0" >google</td>
#       <td id="T_be0c8_row5_col1" class="data row5 col1" >How long will an Airtag work out of range of the phone it was setup on?</td>
#       <td id="T_be0c8_row5_col2" class="data row5 col2" >long airtag work rang phone setup</td>
#       <td id="T_be0c8_row5_col3" class="data row5 col3" >-0.050000</td>
#       <td id="T_be0c8_row5_col4" class="data row5 col4" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be0c8_row6_col0" class="data row6 col0" >google</td>
#       <td id="T_be0c8_row6_col1" class="data row6 col1" >Apple Watch vs Fitbit calorie count. Why are they different?</td>
#       <td id="T_be0c8_row6_col2" class="data row6 col2" >appl watch fitbit calori count differ</td>
#       <td id="T_be0c8_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_be0c8_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be0c8_row7_col0" class="data row7 col0" >google</td>
#       <td id="T_be0c8_row7_col1" class="data row7 col1" >Keep Your Kids Entertained for Hours with Our Colouring and Drawing App!</td>
#       <td id="T_be0c8_row7_col2" class="data row7 col2" >keep kid entertain hour colour draw app</td>
#       <td id="T_be0c8_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_be0c8_row7_col4" class="data row7 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be0c8_row8_col0" class="data row8 col0" >google</td>
#       <td id="T_be0c8_row8_col1" class="data row8 col1" >lo-rain has now fireflies</td>
#       <td id="T_be0c8_row8_col2" class="data row8 col2" >rain firefli</td>
#       <td id="T_be0c8_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_be0c8_row8_col4" class="data row8 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_be0c8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be0c8_row9_col0" class="data row9 col0" >google</td>
#       <td id="T_be0c8_row9_col1" class="data row9 col1" >Apple will use 100 percent recycled cobalt in batteries by 2025 | Industry-leading innovation paves new path for key recycled metals in batteries, magnets, and circuit boards</td>
#       <td id="T_be0c8_row9_col2" class="data row9 col2" >appl use percent recycl cobalt batteri industri lead innov pave new path key recycl metal batteri magnet circuit board</td>
#       <td id="T_be0c8_row9_col3" class="data row9 col3" >0.068182</td>
#       <td id="T_be0c8_row9_col4" class="data row9 col4" >Positive</td>
#     </tr>
#   </tbody>
# </table>

# %%
"""
Senitment Analysis using vader
"""
import praw
import pandas as pd
import re
import nltk
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Reddit API credentials
reddit_client_id = 'NgboStGHqM88bILBVSkjnQ'
reddit_client_secret = '-ik8I0QbDR5wmZZdKdpd_L_6KVoN0Q'
reddit_username = 'UnusualAd8451'
reddit_password = 'datamining1234'
reddit_user_agent = 'SentimentAnalysisBot/0.1'

# Authenticate with the Reddit API using PRAW
reddit = praw.Reddit(client_id=reddit_client_id, 
                     client_secret=reddit_client_secret, 
                     username=reddit_username, 
                     password=reddit_password, 
                     user_agent=reddit_user_agent)

# Function to preprocess post text
def preprocess_post(post):
    # Remove URLs
    post = re.sub(r'http\S+|www\S+|https\S+', '', post, flags=re.MULTILINE)
    
    # Remove special characters and numbers
    post = re.sub(r'\W', ' ', post)
    post = re.sub(r'\d', ' ', post)
    
    # Convert to lowercase
    post = post.lower()
    
    # Tokenize
    tokens = word_tokenize(post)
    
    # Remove stop words and stem the remaining words
    stop_words = set(stopwords.words('english'))
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens if token not in stop_words and len(token) > 2]
    
    # Reconstruct the preprocessed post text
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# List of subreddits to collect posts and analyze sentiment for
subreddits = ["apple", "microsoft", "amazon", "teslamotors", "google"]

# List to store preprocessed posts
preprocessed_posts = []

# List to store raw posts
raw_posts = []

# List to store sentiment scores for each subreddit
sentiment_scores = []

# List to store sentiment descriptions for each score
sentiment_descriptions = []

# Initialize Vader sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Loop through each subreddit and collect 1000 posts
for subreddit in subreddits:
    print(f"Collecting posts for r/{subreddit}...")
    posts = reddit.subreddit(subreddit).hot(limit=1000)
    
    # Analyze the sentiment of each post
    for post in posts:
        # Preprocess the post text
        preprocessed_text = preprocess_post(post.title)
        preprocessed_posts.append(preprocessed_text)
        
        # Append the raw post text to the list
        raw_posts.append(post.title)
        
        # Analyze the sentiment of the preprocessed post text using Vader
        sentiment_score = sia.polarity_scores(preprocessed_text)['compound']
        sentiment_scores.append(sentiment_score)
        
        # Determine the sentiment description based on the sentiment score
        if sentiment_score > 0.05:
            sentiment_description = "Positive"
        elif sentiment_score < -0.05:
            sentiment_description = "Negative"
        else:
            sentiment_description = "Neutral"
        sentiment_descriptions.append(sentiment_description)

data = {"Subreddit": subreddits * len(preprocessed_posts),
        "Raw Text": raw_posts * len(subreddits),
        "Post": preprocessed_posts * len(subreddits),
        "Sentiment Score": sentiment_scores * len(subreddits),
        "Sentiment Description": sentiment_descriptions * len(subreddits)}
df = pd.DataFrame(data)

apple_df = df[df['Subreddit'] == 'apple'].reset_index(drop=True)
print("\nApple Average Sentiment Score:", apple_df['Sentiment Score'].mean())
display(apple_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Apple DataFrame"))

microsoft_df = df[df['Subreddit'] == 'microsoft'].reset_index(drop=True)
print("Microsoft Average Sentiment Score:", microsoft_df['Sentiment Score'].mean())
display(microsoft_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Microsoft DataFrame"))

amazon_df = df[df['Subreddit'] == 'amazon'].reset_index(drop=True)
print("Amazon Average Sentiment Score:", amazon_df['Sentiment Score'].mean())
display(amazon_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Amazon DataFrame"))

tesla_df = df[df['Subreddit'] == 'teslamotors'].reset_index(drop=True)
print("Tesla Average Sentiment Score:", tesla_df['Sentiment Score'].mean())
display(tesla_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Tesla DataFrame"))

google_df = df[df['Subreddit'] == 'google'].reset_index(drop=True)
print("Google Average Sentiment Score:", google_df['Sentiment Score'].mean())
display(google_df.head(10).style.set_properties(**{'text-align': 'left'}).set_table_styles([{'selector': 'th', 'props': [('text-align', 'left')]}]).set_caption("Google DataFrame"))
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/htootayzaaung/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Collecting posts for r/apple...
# Collecting posts for r/microsoft...
# Collecting posts for r/amazon...
# Collecting posts for r/teslamotors...
# Collecting posts for r/google...
#
# Apple Average Sentiment Score: 0.0379529527559053
# <style type="text/css">
# #T_34aec th {
#   text-align: left;
# }
# #T_34aec_row0_col0, #T_34aec_row0_col1, #T_34aec_row0_col2, #T_34aec_row0_col3, #T_34aec_row0_col4, #T_34aec_row1_col0, #T_34aec_row1_col1, #T_34aec_row1_col2, #T_34aec_row1_col3, #T_34aec_row1_col4, #T_34aec_row2_col0, #T_34aec_row2_col1, #T_34aec_row2_col2, #T_34aec_row2_col3, #T_34aec_row2_col4, #T_34aec_row3_col0, #T_34aec_row3_col1, #T_34aec_row3_col2, #T_34aec_row3_col3, #T_34aec_row3_col4, #T_34aec_row4_col0, #T_34aec_row4_col1, #T_34aec_row4_col2, #T_34aec_row4_col3, #T_34aec_row4_col4, #T_34aec_row5_col0, #T_34aec_row5_col1, #T_34aec_row5_col2, #T_34aec_row5_col3, #T_34aec_row5_col4, #T_34aec_row6_col0, #T_34aec_row6_col1, #T_34aec_row6_col2, #T_34aec_row6_col3, #T_34aec_row6_col4, #T_34aec_row7_col0, #T_34aec_row7_col1, #T_34aec_row7_col2, #T_34aec_row7_col3, #T_34aec_row7_col4, #T_34aec_row8_col0, #T_34aec_row8_col1, #T_34aec_row8_col2, #T_34aec_row8_col3, #T_34aec_row8_col4, #T_34aec_row9_col0, #T_34aec_row9_col1, #T_34aec_row9_col2, #T_34aec_row9_col3, #T_34aec_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_34aec">
#   <caption>Apple DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34aec_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_34aec_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_34aec_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_34aec_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_34aec_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34aec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34aec_row0_col0" class="data row0 col0" >apple</td>
#       <td id="T_34aec_row0_col1" class="data row0 col1" >Daily Advice Thread - April 17, 2023</td>
#       <td id="T_34aec_row0_col2" class="data row0 col2" >daili advic thread april</td>
#       <td id="T_34aec_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_34aec_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34aec_row1_col0" class="data row1 col0" >apple</td>
#       <td id="T_34aec_row1_col1" class="data row1 col1" >Rumor: iPhone 15 to use 'frosted glass' finish, new 'cyan' color option</td>
#       <td id="T_34aec_row1_col2" class="data row1 col2" >rumor iphon use frost glass finish new cyan color option</td>
#       <td id="T_34aec_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_34aec_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34aec_row2_col0" class="data row2 col0" >apple</td>
#       <td id="T_34aec_row2_col1" class="data row2 col1" >Tim Cook spotted at Coachella with Eddy Cue</td>
#       <td id="T_34aec_row2_col2" class="data row2 col2" >tim cook spot coachella eddi cue</td>
#       <td id="T_34aec_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_34aec_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34aec_row3_col0" class="data row3 col0" >apple</td>
#       <td id="T_34aec_row3_col1" class="data row3 col1" >Live in an apartment? Tired of buzzing people in? I made an app to turn any buzzer into a smart device</td>
#       <td id="T_34aec_row3_col2" class="data row3 col2" >live apart tire buzz peopl made app turn buzzer smart devic</td>
#       <td id="T_34aec_row3_col3" class="data row3 col3" >0.401900</td>
#       <td id="T_34aec_row3_col4" class="data row3 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34aec_row4_col0" class="data row4 col0" >apple</td>
#       <td id="T_34aec_row4_col1" class="data row4 col1" >Pockity: Simple personal budgeting and expense tracking for iOS & iPadOS</td>
#       <td id="T_34aec_row4_col2" class="data row4 col2" >pockiti simpl person budget expens track io ipado</td>
#       <td id="T_34aec_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_34aec_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34aec_row5_col0" class="data row5 col0" >apple</td>
#       <td id="T_34aec_row5_col1" class="data row5 col1" >Hello drivers on Reddit! I made a dashcam + turn-by-turn navigation app.</td>
#       <td id="T_34aec_row5_col2" class="data row5 col2" >hello driver reddit made dashcam turn turn navig app</td>
#       <td id="T_34aec_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_34aec_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34aec_row6_col0" class="data row6 col0" >apple</td>
#       <td id="T_34aec_row6_col1" class="data row6 col1" >‘A huge blunder’: GM’s decision to ditch Apple CarPlay, Android Auto sparks backlash</td>
#       <td id="T_34aec_row6_col2" class="data row6 col2" >huge blunder decis ditch appl carplay android auto spark backlash</td>
#       <td id="T_34aec_row6_col3" class="data row6 col3" >0.493900</td>
#       <td id="T_34aec_row6_col4" class="data row6 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34aec_row7_col0" class="data row7 col0" >apple</td>
#       <td id="T_34aec_row7_col1" class="data row7 col1" >Apple Watch vs Fitbit calorie count. Why are they different?</td>
#       <td id="T_34aec_row7_col2" class="data row7 col2" >appl watch fitbit calori count differ</td>
#       <td id="T_34aec_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_34aec_row7_col4" class="data row7 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34aec_row8_col0" class="data row8 col0" >apple</td>
#       <td id="T_34aec_row8_col1" class="data row8 col1" >Apple Makes Headway on New Mac Laptops as It Grapples With Slump</td>
#       <td id="T_34aec_row8_col2" class="data row8 col2" >appl make headway new mac laptop grappl slump</td>
#       <td id="T_34aec_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_34aec_row8_col4" class="data row8 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_34aec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34aec_row9_col0" class="data row9 col0" >apple</td>
#       <td id="T_34aec_row9_col1" class="data row9 col1" >How Apple is making the chips that power its computers – and why its Macs are turning green</td>
#       <td id="T_34aec_row9_col2" class="data row9 col2" >appl make chip power comput mac turn green</td>
#       <td id="T_34aec_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_34aec_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
# Microsoft Average Sentiment Score: 0.031341929133858144
# <style type="text/css">
# #T_dddce th {
#   text-align: left;
# }
# #T_dddce_row0_col0, #T_dddce_row0_col1, #T_dddce_row0_col2, #T_dddce_row0_col3, #T_dddce_row0_col4, #T_dddce_row1_col0, #T_dddce_row1_col1, #T_dddce_row1_col2, #T_dddce_row1_col3, #T_dddce_row1_col4, #T_dddce_row2_col0, #T_dddce_row2_col1, #T_dddce_row2_col2, #T_dddce_row2_col3, #T_dddce_row2_col4, #T_dddce_row3_col0, #T_dddce_row3_col1, #T_dddce_row3_col2, #T_dddce_row3_col3, #T_dddce_row3_col4, #T_dddce_row4_col0, #T_dddce_row4_col1, #T_dddce_row4_col2, #T_dddce_row4_col3, #T_dddce_row4_col4, #T_dddce_row5_col0, #T_dddce_row5_col1, #T_dddce_row5_col2, #T_dddce_row5_col3, #T_dddce_row5_col4, #T_dddce_row6_col0, #T_dddce_row6_col1, #T_dddce_row6_col2, #T_dddce_row6_col3, #T_dddce_row6_col4, #T_dddce_row7_col0, #T_dddce_row7_col1, #T_dddce_row7_col2, #T_dddce_row7_col3, #T_dddce_row7_col4, #T_dddce_row8_col0, #T_dddce_row8_col1, #T_dddce_row8_col2, #T_dddce_row8_col3, #T_dddce_row8_col4, #T_dddce_row9_col0, #T_dddce_row9_col1, #T_dddce_row9_col2, #T_dddce_row9_col3, #T_dddce_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_dddce">
#   <caption>Microsoft DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dddce_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_dddce_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_dddce_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_dddce_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_dddce_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dddce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dddce_row0_col0" class="data row0 col0" >microsoft</td>
#       <td id="T_dddce_row0_col1" class="data row0 col1" >Apple Announces WWDC 2023 Event Taking Place June 5 to 9</td>
#       <td id="T_dddce_row0_col2" class="data row0 col2" >appl announc wwdc event take place june</td>
#       <td id="T_dddce_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_dddce_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dddce_row1_col0" class="data row1 col0" >microsoft</td>
#       <td id="T_dddce_row1_col1" class="data row1 col1" >Apple launches all-new ‘Apple Trade In’ website in time for Earth Day</td>
#       <td id="T_dddce_row1_col2" class="data row1 col2" >appl launch new appl trade websit time earth day</td>
#       <td id="T_dddce_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_dddce_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dddce_row2_col0" class="data row2 col0" >microsoft</td>
#       <td id="T_dddce_row2_col1" class="data row2 col1" >Apple will lay sideloading groundwork in iOS 17</td>
#       <td id="T_dddce_row2_col2" class="data row2 col2" >appl lay sideload groundwork io</td>
#       <td id="T_dddce_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_dddce_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dddce_row3_col0" class="data row3 col0" >microsoft</td>
#       <td id="T_dddce_row3_col1" class="data row3 col1" >Fanciful Fonts - add custom fonts and text effects to iMessage and more</td>
#       <td id="T_dddce_row3_col2" class="data row3 col2" >fanci font add custom font text effect imessag</td>
#       <td id="T_dddce_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_dddce_row3_col4" class="data row3 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dddce_row4_col0" class="data row4 col0" >microsoft</td>
#       <td id="T_dddce_row4_col1" class="data row4 col1" >iPhone 3g Commercial "There's An App For That" 2009</td>
#       <td id="T_dddce_row4_col2" class="data row4 col2" >iphon commerci app</td>
#       <td id="T_dddce_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_dddce_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dddce_row5_col0" class="data row5 col0" >microsoft</td>
#       <td id="T_dddce_row5_col1" class="data row5 col1" >The macOS version of Chrome gets a 10% increase in performance</td>
#       <td id="T_dddce_row5_col2" class="data row5 col2" >maco version chrome get increas perform</td>
#       <td id="T_dddce_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_dddce_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dddce_row6_col0" class="data row6 col0" >microsoft</td>
#       <td id="T_dddce_row6_col1" class="data row6 col1" >Why do stores have to individually roll out Apple pay in the US ? How does that work?</td>
#       <td id="T_dddce_row6_col2" class="data row6 col2" >store individu roll appl pay work</td>
#       <td id="T_dddce_row6_col3" class="data row6 col3" >-0.102700</td>
#       <td id="T_dddce_row6_col4" class="data row6 col4" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dddce_row7_col0" class="data row7 col0" >microsoft</td>
#       <td id="T_dddce_row7_col1" class="data row7 col1" >Siri on HomePod actively ruins the user experience</td>
#       <td id="T_dddce_row7_col2" class="data row7 col2" >siri homepod activ ruin user experi</td>
#       <td id="T_dddce_row7_col3" class="data row7 col3" >-0.585900</td>
#       <td id="T_dddce_row7_col4" class="data row7 col4" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dddce_row8_col0" class="data row8 col0" >microsoft</td>
#       <td id="T_dddce_row8_col1" class="data row8 col1" >This speech gives me goosebumps every time. It's the best Steve Jobs motivational speech. Also, the movie "Jobs" (2013) is my all-time favorite.</td>
#       <td id="T_dddce_row8_col2" class="data row8 col2" >speech give goosebump everi time best steve job motiv speech also movi job time favorit</td>
#       <td id="T_dddce_row8_col3" class="data row8 col3" >0.636900</td>
#       <td id="T_dddce_row8_col4" class="data row8 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_dddce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dddce_row9_col0" class="data row9 col0" >microsoft</td>
#       <td id="T_dddce_row9_col1" class="data row9 col1" >Apple's iPhone SE 4 is reportedly a 5G engineering test, and not for sale</td>
#       <td id="T_dddce_row9_col2" class="data row9 col2" >appl iphon reportedli engin test sale</td>
#       <td id="T_dddce_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_dddce_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
# Amazon Average Sentiment Score: 0.037943897637795175
# <style type="text/css">
# #T_4bd27 th {
#   text-align: left;
# }
# #T_4bd27_row0_col0, #T_4bd27_row0_col1, #T_4bd27_row0_col2, #T_4bd27_row0_col3, #T_4bd27_row0_col4, #T_4bd27_row1_col0, #T_4bd27_row1_col1, #T_4bd27_row1_col2, #T_4bd27_row1_col3, #T_4bd27_row1_col4, #T_4bd27_row2_col0, #T_4bd27_row2_col1, #T_4bd27_row2_col2, #T_4bd27_row2_col3, #T_4bd27_row2_col4, #T_4bd27_row3_col0, #T_4bd27_row3_col1, #T_4bd27_row3_col2, #T_4bd27_row3_col3, #T_4bd27_row3_col4, #T_4bd27_row4_col0, #T_4bd27_row4_col1, #T_4bd27_row4_col2, #T_4bd27_row4_col3, #T_4bd27_row4_col4, #T_4bd27_row5_col0, #T_4bd27_row5_col1, #T_4bd27_row5_col2, #T_4bd27_row5_col3, #T_4bd27_row5_col4, #T_4bd27_row6_col0, #T_4bd27_row6_col1, #T_4bd27_row6_col2, #T_4bd27_row6_col3, #T_4bd27_row6_col4, #T_4bd27_row7_col0, #T_4bd27_row7_col1, #T_4bd27_row7_col2, #T_4bd27_row7_col3, #T_4bd27_row7_col4, #T_4bd27_row8_col0, #T_4bd27_row8_col1, #T_4bd27_row8_col2, #T_4bd27_row8_col3, #T_4bd27_row8_col4, #T_4bd27_row9_col0, #T_4bd27_row9_col1, #T_4bd27_row9_col2, #T_4bd27_row9_col3, #T_4bd27_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_4bd27">
#   <caption>Amazon DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bd27_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_4bd27_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_4bd27_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_4bd27_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_4bd27_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bd27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bd27_row0_col0" class="data row0 col0" >amazon</td>
#       <td id="T_4bd27_row0_col1" class="data row0 col1" >Apple Card’s new high-yield Savings account is now available, offering a 4.15 percent APY</td>
#       <td id="T_4bd27_row0_col2" class="data row0 col2" >appl card new high yield save account avail offer percent api</td>
#       <td id="T_4bd27_row0_col3" class="data row0 col3" >0.493900</td>
#       <td id="T_4bd27_row0_col4" class="data row0 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bd27_row1_col0" class="data row1 col0" >amazon</td>
#       <td id="T_4bd27_row1_col1" class="data row1 col1" >LG Display developing new OLED etching tech for Apple</td>
#       <td id="T_4bd27_row1_col2" class="data row1 col2" >display develop new ole etch tech appl</td>
#       <td id="T_4bd27_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_4bd27_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bd27_row2_col0" class="data row2 col0" >amazon</td>
#       <td id="T_4bd27_row2_col1" class="data row2 col1" >Apple Plans to Launch More Than Just Its New Headset at WWDC</td>
#       <td id="T_4bd27_row2_col2" class="data row2 col2" >appl plan launch new headset wwdc</td>
#       <td id="T_4bd27_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_4bd27_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bd27_row3_col0" class="data row3 col0" >amazon</td>
#       <td id="T_4bd27_row3_col1" class="data row3 col1" >Mac OS X 10.2 Jaguar Video - "Touching", 2002</td>
#       <td id="T_4bd27_row3_col2" class="data row3 col2" >mac jaguar video touch</td>
#       <td id="T_4bd27_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_4bd27_row3_col4" class="data row3 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4bd27_row4_col0" class="data row4 col0" >amazon</td>
#       <td id="T_4bd27_row4_col1" class="data row4 col1" >Apple is selling a 10 year old refurbished computer for £5149</td>
#       <td id="T_4bd27_row4_col2" class="data row4 col2" >appl sell year old refurbish comput</td>
#       <td id="T_4bd27_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_4bd27_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4bd27_row5_col0" class="data row5 col0" >amazon</td>
#       <td id="T_4bd27_row5_col1" class="data row5 col1" >Daily Advice Thread - April 16, 2023</td>
#       <td id="T_4bd27_row5_col2" class="data row5 col2" >daili advic thread april</td>
#       <td id="T_4bd27_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_4bd27_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4bd27_row6_col0" class="data row6 col0" >amazon</td>
#       <td id="T_4bd27_row6_col1" class="data row6 col1" >Apple reportedly testing 15-inch MacBook Air production</td>
#       <td id="T_4bd27_row6_col2" class="data row6 col2" >appl reportedli test inch macbook air product</td>
#       <td id="T_4bd27_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_4bd27_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4bd27_row7_col0" class="data row7 col0" >amazon</td>
#       <td id="T_4bd27_row7_col1" class="data row7 col1" >First iPhone. A Guided Tour by Apple</td>
#       <td id="T_4bd27_row7_col2" class="data row7 col2" >first iphon guid tour appl</td>
#       <td id="T_4bd27_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_4bd27_row7_col4" class="data row7 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4bd27_row8_col0" class="data row8 col0" >amazon</td>
#       <td id="T_4bd27_row8_col1" class="data row8 col1" >Apple TV 4K launching huge upgrade for sports fans this weekend — how to get it</td>
#       <td id="T_4bd27_row8_col2" class="data row8 col2" >appl launch huge upgrad sport fan weekend get</td>
#       <td id="T_4bd27_row8_col3" class="data row8 col3" >0.557400</td>
#       <td id="T_4bd27_row8_col4" class="data row8 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_4bd27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4bd27_row9_col0" class="data row9 col0" >amazon</td>
#       <td id="T_4bd27_row9_col1" class="data row9 col1" >Why do I continue to see News+ stories headed “See these photos!” that contain no photos?</td>
#       <td id="T_4bd27_row9_col2" class="data row9 col2" >continu see news stori head see photo contain photo</td>
#       <td id="T_4bd27_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_4bd27_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
# Tesla Average Sentiment Score: 0.05108503937007866
# <style type="text/css">
# #T_b2bee th {
#   text-align: left;
# }
# #T_b2bee_row0_col0, #T_b2bee_row0_col1, #T_b2bee_row0_col2, #T_b2bee_row0_col3, #T_b2bee_row0_col4, #T_b2bee_row1_col0, #T_b2bee_row1_col1, #T_b2bee_row1_col2, #T_b2bee_row1_col3, #T_b2bee_row1_col4, #T_b2bee_row2_col0, #T_b2bee_row2_col1, #T_b2bee_row2_col2, #T_b2bee_row2_col3, #T_b2bee_row2_col4, #T_b2bee_row3_col0, #T_b2bee_row3_col1, #T_b2bee_row3_col2, #T_b2bee_row3_col3, #T_b2bee_row3_col4, #T_b2bee_row4_col0, #T_b2bee_row4_col1, #T_b2bee_row4_col2, #T_b2bee_row4_col3, #T_b2bee_row4_col4, #T_b2bee_row5_col0, #T_b2bee_row5_col1, #T_b2bee_row5_col2, #T_b2bee_row5_col3, #T_b2bee_row5_col4, #T_b2bee_row6_col0, #T_b2bee_row6_col1, #T_b2bee_row6_col2, #T_b2bee_row6_col3, #T_b2bee_row6_col4, #T_b2bee_row7_col0, #T_b2bee_row7_col1, #T_b2bee_row7_col2, #T_b2bee_row7_col3, #T_b2bee_row7_col4, #T_b2bee_row8_col0, #T_b2bee_row8_col1, #T_b2bee_row8_col2, #T_b2bee_row8_col3, #T_b2bee_row8_col4, #T_b2bee_row9_col0, #T_b2bee_row9_col1, #T_b2bee_row9_col2, #T_b2bee_row9_col3, #T_b2bee_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_b2bee">
#   <caption>Tesla DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2bee_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_b2bee_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_b2bee_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_b2bee_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_b2bee_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2bee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2bee_row0_col0" class="data row0 col0" >teslamotors</td>
#       <td id="T_b2bee_row0_col1" class="data row0 col1" >iPhone 15 Pro 'Action' Button to Replace Role of Volume Buttons When Performing a Power Off/Force Restart</td>
#       <td id="T_b2bee_row0_col2" class="data row0 col2" >iphon pro action button replac role volum button perform power forc restart</td>
#       <td id="T_b2bee_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b2bee_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2bee_row1_col0" class="data row1 col0" >teslamotors</td>
#       <td id="T_b2bee_row1_col1" class="data row1 col1" >Apple Savings Account: Arbitration Provision (Read!)</td>
#       <td id="T_b2bee_row1_col2" class="data row1 col2" >appl save account arbitr provis read</td>
#       <td id="T_b2bee_row1_col3" class="data row1 col3" >0.493900</td>
#       <td id="T_b2bee_row1_col4" class="data row1 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b2bee_row2_col0" class="data row2 col0" >teslamotors</td>
#       <td id="T_b2bee_row2_col1" class="data row2 col1" >Rant: Apple’s software quality (control)</td>
#       <td id="T_b2bee_row2_col2" class="data row2 col2" >rant appl softwar qualiti control</td>
#       <td id="T_b2bee_row2_col3" class="data row2 col3" >-0.340000</td>
#       <td id="T_b2bee_row2_col4" class="data row2 col4" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b2bee_row3_col0" class="data row3 col0" >teslamotors</td>
#       <td id="T_b2bee_row3_col1" class="data row3 col1" >As a father in need for some relaxation I made a relaxing sounds app with 30 free sounds for you to create your own calming atmosphere. With a unique Thunderstorm Mode for a realistic experience and no annoying subscription or ads.</td>
#       <td id="T_b2bee_row3_col2" class="data row3 col2" >father need relax made relax sound app free sound creat calm atmospher uniqu thunderstorm mode realist experi annoy subscript ad</td>
#       <td id="T_b2bee_row3_col3" class="data row3 col3" >0.817600</td>
#       <td id="T_b2bee_row3_col4" class="data row3 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b2bee_row4_col0" class="data row4 col0" >teslamotors</td>
#       <td id="T_b2bee_row4_col1" class="data row4 col1" >AppleID and other services down</td>
#       <td id="T_b2bee_row4_col2" class="data row4 col2" >appleid servic</td>
#       <td id="T_b2bee_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_b2bee_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b2bee_row5_col0" class="data row5 col0" >teslamotors</td>
#       <td id="T_b2bee_row5_col1" class="data row5 col1" >CamPlan combines AR with AI to create modern floor plans and get interior design advice.</td>
#       <td id="T_b2bee_row5_col2" class="data row5 col2" >camplan combin creat modern floor plan get interior design advic</td>
#       <td id="T_b2bee_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_b2bee_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b2bee_row6_col0" class="data row6 col0" >teslamotors</td>
#       <td id="T_b2bee_row6_col1" class="data row6 col1" >AirPods Are a Tragedy</td>
#       <td id="T_b2bee_row6_col2" class="data row6 col2" >airpod tragedi</td>
#       <td id="T_b2bee_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_b2bee_row6_col4" class="data row6 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b2bee_row7_col0" class="data row7 col0" >teslamotors</td>
#       <td id="T_b2bee_row7_col1" class="data row7 col1" >Gurman: 15-Inch MacBook Air With M2-Like Chip Spotted in Developer Logs</td>
#       <td id="T_b2bee_row7_col2" class="data row7 col2" >gurman inch macbook air like chip spot develop log</td>
#       <td id="T_b2bee_row7_col3" class="data row7 col3" >0.361200</td>
#       <td id="T_b2bee_row7_col4" class="data row7 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b2bee_row8_col0" class="data row8 col0" >teslamotors</td>
#       <td id="T_b2bee_row8_col1" class="data row8 col1" >Daily Advice Thread - April 15, 2023</td>
#       <td id="T_b2bee_row8_col2" class="data row8 col2" >daili advic thread april</td>
#       <td id="T_b2bee_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_b2bee_row8_col4" class="data row8 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_b2bee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b2bee_row9_col0" class="data row9 col0" >teslamotors</td>
#       <td id="T_b2bee_row9_col1" class="data row9 col1" >Watched this today and had a huge wave of nostalgia</td>
#       <td id="T_b2bee_row9_col2" class="data row9 col2" >watch today huge wave nostalgia</td>
#       <td id="T_b2bee_row9_col3" class="data row9 col3" >0.318200</td>
#       <td id="T_b2bee_row9_col4" class="data row9 col4" >Positive</td>
#     </tr>
#   </tbody>
# </table>
# Google Average Sentiment Score: 0.054685433070865944
# <style type="text/css">
# #T_2edc9 th {
#   text-align: left;
# }
# #T_2edc9_row0_col0, #T_2edc9_row0_col1, #T_2edc9_row0_col2, #T_2edc9_row0_col3, #T_2edc9_row0_col4, #T_2edc9_row1_col0, #T_2edc9_row1_col1, #T_2edc9_row1_col2, #T_2edc9_row1_col3, #T_2edc9_row1_col4, #T_2edc9_row2_col0, #T_2edc9_row2_col1, #T_2edc9_row2_col2, #T_2edc9_row2_col3, #T_2edc9_row2_col4, #T_2edc9_row3_col0, #T_2edc9_row3_col1, #T_2edc9_row3_col2, #T_2edc9_row3_col3, #T_2edc9_row3_col4, #T_2edc9_row4_col0, #T_2edc9_row4_col1, #T_2edc9_row4_col2, #T_2edc9_row4_col3, #T_2edc9_row4_col4, #T_2edc9_row5_col0, #T_2edc9_row5_col1, #T_2edc9_row5_col2, #T_2edc9_row5_col3, #T_2edc9_row5_col4, #T_2edc9_row6_col0, #T_2edc9_row6_col1, #T_2edc9_row6_col2, #T_2edc9_row6_col3, #T_2edc9_row6_col4, #T_2edc9_row7_col0, #T_2edc9_row7_col1, #T_2edc9_row7_col2, #T_2edc9_row7_col3, #T_2edc9_row7_col4, #T_2edc9_row8_col0, #T_2edc9_row8_col1, #T_2edc9_row8_col2, #T_2edc9_row8_col3, #T_2edc9_row8_col4, #T_2edc9_row9_col0, #T_2edc9_row9_col1, #T_2edc9_row9_col2, #T_2edc9_row9_col3, #T_2edc9_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_2edc9">
#   <caption>Google DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2edc9_level0_col0" class="col_heading level0 col0" >Subreddit</th>
#       <th id="T_2edc9_level0_col1" class="col_heading level0 col1" >Raw Text</th>
#       <th id="T_2edc9_level0_col2" class="col_heading level0 col2" >Post</th>
#       <th id="T_2edc9_level0_col3" class="col_heading level0 col3" >Sentiment Score</th>
#       <th id="T_2edc9_level0_col4" class="col_heading level0 col4" >Sentiment Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2edc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2edc9_row0_col0" class="data row0 col0" >google</td>
#       <td id="T_2edc9_row0_col1" class="data row0 col1" >Tim Cook is in Mumbai to launch Apple’s first store in India.</td>
#       <td id="T_2edc9_row0_col2" class="data row0 col2" >tim cook mumbai launch appl first store india</td>
#       <td id="T_2edc9_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_2edc9_row0_col4" class="data row0 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2edc9_row1_col0" class="data row1 col0" >google</td>
#       <td id="T_2edc9_row1_col1" class="data row1 col1" >watchOS 10 Described as Apple Watch's Biggest Software Update Since 2015</td>
#       <td id="T_2edc9_row1_col2" class="data row1 col2" >watcho describ appl watch biggest softwar updat sinc</td>
#       <td id="T_2edc9_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_2edc9_row1_col4" class="data row1 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2edc9_row2_col0" class="data row2 col0" >google</td>
#       <td id="T_2edc9_row2_col1" class="data row2 col1" >LockBit ransomware gang appears to be targeting Macs for the first time</td>
#       <td id="T_2edc9_row2_col2" class="data row2 col2" >lockbit ransomwar gang appear target mac first time</td>
#       <td id="T_2edc9_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_2edc9_row2_col4" class="data row2 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2edc9_row3_col0" class="data row3 col0" >google</td>
#       <td id="T_2edc9_row3_col1" class="data row3 col1" >Kroger Begins Accepting Apple Pay After Years of Holding Out</td>
#       <td id="T_2edc9_row3_col2" class="data row3 col2" >kroger begin accept appl pay year hold</td>
#       <td id="T_2edc9_row3_col3" class="data row3 col3" >0.296000</td>
#       <td id="T_2edc9_row3_col4" class="data row3 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2edc9_row4_col0" class="data row4 col0" >google</td>
#       <td id="T_2edc9_row4_col1" class="data row4 col1" >Asahi Linux: The team managed to get the Touch Bar working under Linux with KDE, as a secondary display</td>
#       <td id="T_2edc9_row4_col2" class="data row4 col2" >asahi linux team manag get touch bar work linux kde secondari display</td>
#       <td id="T_2edc9_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_2edc9_row4_col4" class="data row4 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2edc9_row5_col0" class="data row5 col0" >google</td>
#       <td id="T_2edc9_row5_col1" class="data row5 col1" >How long will an Airtag work out of range of the phone it was setup on?</td>
#       <td id="T_2edc9_row5_col2" class="data row5 col2" >long airtag work rang phone setup</td>
#       <td id="T_2edc9_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_2edc9_row5_col4" class="data row5 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2edc9_row6_col0" class="data row6 col0" >google</td>
#       <td id="T_2edc9_row6_col1" class="data row6 col1" >If Apple doesn’t introduce something like “old-people mode” this WWDC then it has truly lost its magic.</td>
#       <td id="T_2edc9_row6_col2" class="data row6 col2" >appl introduc someth like old peopl mode wwdc truli lost magic</td>
#       <td id="T_2edc9_row6_col3" class="data row6 col3" >0.051600</td>
#       <td id="T_2edc9_row6_col4" class="data row6 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2edc9_row7_col0" class="data row7 col0" >google</td>
#       <td id="T_2edc9_row7_col1" class="data row7 col1" >Keep Your Kids Entertained for Hours with Our Colouring and Drawing App!</td>
#       <td id="T_2edc9_row7_col2" class="data row7 col2" >keep kid entertain hour colour draw app</td>
#       <td id="T_2edc9_row7_col3" class="data row7 col3" >0.318200</td>
#       <td id="T_2edc9_row7_col4" class="data row7 col4" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2edc9_row8_col0" class="data row8 col0" >google</td>
#       <td id="T_2edc9_row8_col1" class="data row8 col1" >lo-rain has now fireflies</td>
#       <td id="T_2edc9_row8_col2" class="data row8 col2" >rain firefli</td>
#       <td id="T_2edc9_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_2edc9_row8_col4" class="data row8 col4" >Neutral</td>
#     </tr>
#     <tr>
#       <th id="T_2edc9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2edc9_row9_col0" class="data row9 col0" >google</td>
#       <td id="T_2edc9_row9_col1" class="data row9 col1" >Apple will use 100 percent recycled cobalt in batteries by 2025 | Industry-leading innovation paves new path for key recycled metals in batteries, magnets, and circuit boards</td>
#       <td id="T_2edc9_row9_col2" class="data row9 col2" >appl use percent recycl cobalt batteri industri lead innov pave new path key recycl metal batteri magnet circuit board</td>
#       <td id="T_2edc9_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_2edc9_row9_col4" class="data row9 col4" >Neutral</td>
#     </tr>
#   </tbody>
# </table>
